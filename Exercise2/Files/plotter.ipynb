# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
file = "Qlearning-10-goals"
plt.plot(np.loadtxt(file+".csv",delimiter=",",skiprows=1)[:,2])
plt.savefig(file + ".png")

# %%
file = "Qlearning-500-goals"
plt.plot(np.loadtxt(file+".csv",delimiter=",",skiprows=1)[:,2])
plt.savefig(file + ".png")

# %% [markdown]
# ---

# %%
file = "sarsa-10-goals"
plt.plot(np.loadtxt(file+".csv",delimiter=",",skiprows=1)[:,2])
plt.savefig(file + ".png")

# %%
file = "sarsa-500-goals"
plt.plot(np.loadtxt(file+".csv",delimiter=",",skiprows=1)[:,2])
plt.savefig(file + ".png")
